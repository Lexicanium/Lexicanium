Energies | download
https://booksc.org/journal/6591

Artificial Intelligence Review | download
https://booksc.org/journal/2107

International Journal for Numerical Methods in Engineering | download
https://booksc.org/journal/9919

Optimization Letters | download
https://booksc.org/journal/18831

Journal of Retailing and Consumer Services | download
https://booksc.org/journal/15172

Discrete Mathematics Algorithms and Applications | download
https://booksc.org/journal/5942

SSRN Electronic Journal | download
https://booksc.org/journal/22710

Physics Today | download
https://booksc.org/journal/19593

IEEE Aerospace and Electronic Systems Magazine | download
https://booksc.org/journal/9070

Advances in Engineering Software (Thomson Reuters) | download
https://booksc.org/journal/545

Journal of Algorithms & Computational Technology | download
https://booksc.org/journal/12164

Ocean Engineering | download
https://booksc.org/journal/18597

Big Data Mining and Analytics | download
https://booksc.org/journal/54604

Engineering Structures | download
https://booksc.org/journal/6654

Journal of Power Sources | download
https://booksc.org/journal/14990

IEEE Internet Computing | download
https://booksc.org/journal/9108

Algorithmic Finance | download
https://booksc.org/journal/54472

Buildings | download
https://booksc.org/journal/3362

Operations Research | download
https://booksc.org/journal/18767

Journal of Computer Information Systems | download
https://booksc.org/journal/49516

Robotics and Autonomous Systems | download
https://booksc.org/journal/21662

Applied Sciences | download
https://booksc.org/journal/1784

Applied Mathematics and Mechanics | download
https://booksc.org/journal/1747

American Mathematical Monthly | download
https://booksc.org/journal/1154

The Computer Journal | download
https://booksc.org/journal/23567

Journal of the Royal Statistical Society Series B (Methodological) | download
https://booksc.org/journal/15810

Theory Culture & Society | download
https://booksc.org/journal/24674

Cluster Computing | download
https://booksc.org/journal/4577

Neural Computing and Applications | download
https://booksc.org/journal/18033

Reliability Engineering & System Safety | download
https://booksc.org/journal/20839

Journal of Central South University | download
https://booksc.org/journal/12618

Journal of Computers in Education | download
https://booksc.org/journal/27744

Machine Learning and Knowledge Extraction | download
https://booksc.org/journal/55246


"""

# %%
URLS = set([u for u in URLS_TEXT.split("\n") if u.startswith("http")])
URLS
# Out:
# {'https://booksc.org/journal/10037',
#  'https://booksc.org/journal/10215',
#  'https://booksc.org/journal/10263',
#  'https://booksc.org/journal/10425',
#  'https://booksc.org/journal/10443',
#  'https://booksc.org/journal/10549',
#  'https://booksc.org/journal/10636',
#  'https://booksc.org/journal/10638',
#  'https://booksc.org/journal/10677',
#  'https://booksc.org/journal/10680',
#  'https://booksc.org/journal/10709',
#  'https://booksc.org/journal/10727',
#  'https://booksc.org/journal/10820',
#  'https://booksc.org/journal/11047',
#  'https://booksc.org/journal/11074',
#  'https://booksc.org/journal/11179',
#  'https://booksc.org/journal/11428',
#  'https://booksc.org/journal/11529',
#  'https://booksc.org/journal/11530',
#  'https://booksc.org/journal/1154',
#  'https://booksc.org/journal/11731',
#  'https://booksc.org/journal/11791',
#  'https://booksc.org/journal/12156',
#  'https://booksc.org/journal/12163',
#  'https://booksc.org/journal/12164',
# ...

# %%
# %%capture
# !pip install requests bs4
# !pip install tqdm

# %%
import requests
from urllib.parse import urlparse, urljoin
from bs4 import BeautifulSoup
import itertools
from tqdm.contrib.concurrent import thread_map, process_map

# %%
import requests
from urllib.parse import urlparse, urljoin
from bs4 import BeautifulSoup



def is_valid(url):
    """
    Checks whether `url` is a valid URL.
    """
    parsed = urlparse(url)
    return bool(parsed.netloc) and bool(parsed.scheme)


def get_all_website_links(url):
    """
    Returns all URLs that is found on `url` in which it belongs to the same website
    """

    # all URLs of `url`
    urls = set()
    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    for a_tag in soup.findAll("a"):
        href = a_tag.attrs.get("href")
        if href == "" or href is None:
            # href empty tag
            continue
        # join the URL if it's relative (not absolute link)
        href = urljoin(url, href)
        parsed_href = urlparse(href)
        # remove URL GET parameters, URL fragments, etc.
        href = parsed_href.scheme + "://" + parsed_href.netloc + parsed_href.path
        if not is_valid(href):
            # not a valid URL
            continue
        urls.add(href)
    return urls


def crawl(url, max_urls=30):
    """
    Crawls a web page and extracts all links.
    You'll find all links in `external_urls` and `internal_urls` global set variables.
    params:
        max_urls (int): number of max urls to crawl, default is 30.
    """
    #print(f".{url[-5:]}")
    links = get_all_website_links(url)
    #print(f" ..[{len(links)}]..")
    return links
    ### THIS ENABLES RECURSIVE CRAWLING
    #for link in links:
    #    if total_urls_visited > max_urls:
    #        break
    #    crawl(link, max_urls=max_urls)

# %%
r = thread_map(crawl, URLS, max_workers=8)

len(r)
# Out:
#   0%|          | 0/329 [00:00<?, ?it/s]
# 329

# %%
r = set(list(itertools.chain(*r)))
len(r)
# Out:
# 119449

# %%
journal_urls = set([url for url in r if url.startswith("https://booksc.org/journal/")])
len(journal_urls)
# Out:
# 110223

# %%
deep_urls = thread_map(crawl, journal_urls, max_workers=18, chunksize=1)
len(r)
# Out:
#   0%|          | 0/110223 [00:00<?, ?it/s]

# %%
len(deep_urls)
# Out:
# 110223

# %%
r = set(list(itertools.chain(*deep_urls)))
len(r)
# Out:
# 10847023

# %%
r = set(r)
len(r)
# Out:
# 10847023

# %%
pdf_urls = [url for url in r if url.endswith(".pdf")]
len(pdf_urls)
# Out:
# 0

# %%
# !mkdir /data/PAPERS
# %cd /data/PAPERS

# %%
import pandas as pd

df = pd.DataFrame(r)
df.to_csv('00_SCBooks_AllUrls.csv')

# %%
df
# Out:
#                                                        0
# 0                https://booksc.org/book/40339862/0b9f73
# 1             https://te.booksc.org/journal/20141/108/25
# 2                 https://booksc.org/book/4689271/24cc6e
# 3             https://vi.booksc.org/journal/11791/271/14
# 4                  https://booksc.org/author/Rono, Josea
# ...                                                  ...
# 10847018  https://booksc.org/author/Watanabe, Takaaki K.
# 10847019              https://booksc.org/author/Loew, P.
# 10847020      https://booksc.org/author/Zhang, Huan Huan
# 10847021         https://bg.booksc.org/journal/18826/171
# 10847022         https://booksc.org/book/22570378/9a1d65
#
# [10847023 rows x 1 columns]

# %%
import requests
 
def download(url):
  # print("downloading: ",url)
  # assumes that the last segment after the / represents the file name
  # if url is abc/xyz/file.txt, the file name will be file.txt
  file_name_start_pos = url.rfind("/") + 1
  file_name = url[file_name_start_pos:]
 
  r = requests.get(url, stream=True)
  if r.status_code == requests.codes.ok:
    with open(file_name, 'wb') as f:
      for data in r:
        f.write(data)
  return url
 


    
    
r = thread_map(download, pdf_urls, max_workers=18, chunksize=1)
len(r)
