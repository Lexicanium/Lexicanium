# %%
# !conda install -y -c conda-forge jlab-enhanced-cell-toolbar
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/standard/miniconda3
#
#   added / updated specs:
#     - jlab-enhanced-cell-toolbar
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jlab-enhanced-cell-toolbar-3.5.1|     pyhd8ed1ab_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          26 KB
#
# The following NEW packages will be INSTALLED:
#
#   jlab-enhanced-cel~ conda-forge/noarch::jlab-enhanced-cell-toolbar-3.5.1-pyhd8ed1ab_0
#
#
#
# ...
# jlab-enhanced-cell-t | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !pip install --pre jupyter_starters
# Out:
# ...
#      |████████████████████████████████| 408 kB 5.2 MB/s eta 0:00:01
# ...

# %%
# !pip install jupyterlab-tabular-data-editor
# Out:
# ...
#      |████████████████████████████████| 476 kB 2.7 MB/s eta 0:00:01
# ...

# %%
# !conda install -y -c conda-forge ipydatagrid
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/standard/miniconda3
#
#   added / updated specs:
#     - ipydatagrid
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.3.4           |   py39hce1f21e_0         126 KB
#     gast-0.4.0                 |     pyh9f0ad1d_0          12 KB  conda-forge
#     ipydatagrid-1.1.12         |     pyhd8ed1ab_0         2.3 MB  conda-forge
#     ipykernel-5.5.5            |   py39hef51801_0         167 KB  conda-forge
#     ipython-8.4.0              |   py39hf3d152e_0         1.1 MB  conda-forge
#     jinja2-2.11.3              |     pyhd8ed1ab_2          94 KB  conda-forge
#     jupyter_client-7.0.6       |     pyhd8ed1ab_0          87 KB  conda-forge
#     markupsafe-1.1.1           |   py39h3811e60_3          27 KB  conda-forge
# ...

# %%
# !conda install -y -c conda-forge ipympl
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/standard/miniconda3
#
#   added / updated specs:
#     - ipympl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ipympl-0.9.1               |     pyhd8ed1ab_0         347 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         347 KB
#
# The following NEW packages will be INSTALLED:
#
#   ipympl             conda-forge/noarch::ipympl-0.9.1-pyhd8ed1ab_0
#
#
#
# ...
# ipympl-0.9.1         | 347 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -y -c conda-forge ipycanvas
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/standard/miniconda3
#
#   added / updated specs:
#     - ipycanvas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ipycanvas-0.12.0           |     pyhd8ed1ab_1         159 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         159 KB
#
# The following NEW packages will be INSTALLED:
#
#   ipycanvas          conda-forge/noarch::ipycanvas-0.12.0-pyhd8ed1ab_1
#
#
#
# ...
# ipycanvas-0.12.0     | 159 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !pip install ipyurl
# Out:
# ...
#      |████████████████████████████████| 762 kB 3.5 MB/s eta 0:00:01
# ...

# %% [markdown]
# https://hub-binder.mybinder.ovh/user/teia_engineering-ipydatatable-dk488a2q/notebooks/examples/Intro%20to%20ipydatatable.ipynb

# %%
# !pip install ipydatatable
# Out:
# ...
#      |████████████████████████████████| 4.6 MB 6.1 MB/s eta 0:00:01
# ...

# %%
# !conda install -y -c conda-forge nodejs
# !conda upgrade -y -c conda-forge nodejs
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/standard/miniconda3
#
#   added / updated specs:
#     - nodejs
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |       2_kmp_llvm           6 KB  conda-forge
#     alsa-lib-1.2.6.1           |       h7f98852_0         578 KB  conda-forge
#     aom-3.4.0                  |       h27087fc_1         2.7 MB  conda-forge
#     argon2-cffi-bindings-21.2.0|   py39hb9d737c_2          34 KB  conda-forge
#     attr-2.5.1                 |       h166bdaf_1          69 KB  conda-forge
#     brotli-1.0.9               |       h166bdaf_7          18 KB  conda-forge
#     brotli-bin-1.0.9           |       h166bdaf_7          19 KB  conda-forge
# ...

# %%
# !pip install jupyter-wysiwyg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.6 MB/s eta 0:00:00ta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.8/120.8 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 kB 10.0 MB/s eta 0:00:00
# ...

# %%
# !jupyter labextension install @techrah/text-shortcuts
# Out:
# Building jupyterlab assets (production, minimized)
# /
