# %% [markdown]
# has directories with symbolic links per label:
#
#    - medical/flashcards
#    - medical/textbooks
#    - medical/misc
#    - bio
#    - biotech
#    - cs/ml
#    - cs/ml_nlp
#    - cs/oreilly
#    - cs/grokking
#    - cs/manning
#    - cs/misc
#    - intro
#    - intro/oxford_very
#    - math
#    - popsci/math
#    - popsci/misc
#    - popsci/antropology
#    - popsci/cs
#    - paper_copy
#
#  1. metadata guessor using good reads dataset
#
#  metadata / pdf viewer, tagger, ( authors publishing  isbn) in notebook
#
#
#  has directories with formats that mirror structure:
#
#    - pdf
#    - txt
#    - csv_metadata
#    - pkl
#    - epub
#    - pdf_10_5
#    - png_1
#    - jpg_highlighted
#    - csv_highlighted
#    - csv_highlighted_autogenerated
#    - pdf_highlighted_autogenerated
#    - mp3
#    - mp3_10
#    - csv_index
#    - csv_contents
#    - csv_figures
#    - png_figures
#    - latex_figures
#    - nfo_figures
#    - markdown
#    - html
#
#
#    a desktop /mobile swift application that allows to label pdf documents
