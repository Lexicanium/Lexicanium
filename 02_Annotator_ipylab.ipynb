# %% [markdown]
# https://ipyevents.readthedocs.io/en/latest/?badge=latest

# %%
# !conda create -y -n ipylab-examples -c conda-forge jupyterlab ipylab ipytree bqplot ipywidgets numpy
# !conda activate ipylab-examples
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/standard/miniconda3/envs/ipylab-examples
#
#   added / updated specs:
#     - bqplot
#     - ipylab
#     - ipytree
#     - ipywidgets
#     - jupyterlab
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     anyio-3.6.1                |     pyhd8ed1ab_1          83 KB  conda-forge
#     argon2-cffi-21.3.0         |     pyhd8ed1ab_0          15 KB  conda-forge
#     argon2-cffi-bindings-21.2.0|  py310h5764c6d_2          34 KB  conda-forge
#     asttokens-2.0.5            |     pyhd8ed1ab_0          21 KB  conda-forge
#     babel-2.10.3               |     pyhd8ed1ab_0         6.7 MB  conda-forge
# ...

# %%
# !conda install -c conda-forge ipyevents
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/standard/miniconda3
#
#   added / updated specs:
#     - ipyevents
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ipyevents-2.0.1            |     pyhd8ed1ab_0          58 KB  conda-forge
#     ipykernel-5.5.5            |   py39hef51801_0         167 KB  conda-forge
#     ipython-8.4.0              |   py39hf3d152e_0         1.1 MB  conda-forge
#     jinja2-2.11.3              |     pyhd8ed1ab_2          94 KB  conda-forge
#     jupyter_client-7.0.6       |     pyhd8ed1ab_0          87 KB  conda-forge
#     markupsafe-1.1.1           |   py39h3811e60_3          27 KB  conda-forge
#     mistune-0.8.4              |py39h3811e60_1004          54 KB  conda-forge
#     nbconvert-5.6.1            |     pyhd8ed1ab_2         373 KB  conda-forge
# ...
